# %%
import torch
print("torch   :", torch.__version__)
print("CUDA    :", torch.version.cuda)
print("GPU OK  :", torch.cuda.is_available())
print("GPU     :", torch.cuda.get_device_name(0))

# %%
Skip to Main
tinyunetablation
Last Checkpoint: 37 minutes ago
[TinyUNet (CUDA 12.4)]
import torch
print("torch   :", torch.__version__)
print("CUDA    :", torch.version.cuda)
print("GPU OK  :", torch.cuda.is_available())
print("GPU     :", torch.cuda.get_device_name(0))

torch   : 2.4.0+cu124
CUDA    : 12.4
GPU OK  : True
GPU     : NVIDIA L40S-16Q

# %%
# !ls

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model attentionunet \
--base_channels 32 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/attentionunet32 \
--resume  outputs/attentionunet32/best_model.pth

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model resunet \
--base_channels 32 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/resunet32

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model unet \
--base_channels 32 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/unet32

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model tinyunet_edge \
--base_channels 16 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/tinyunet_edge

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model tinyunet_edge_ds \
--base_channels 16 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/tinyunet_edge_ds

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model attentionunet \
--base_channels 32 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/attentionunet

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model tinyunet_full \
--base_channels 32 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/tinyunet32_full

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model tinyunet_full \
--base_channels 16 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/tinyunet16_full \
--resume outputs/tinyunet16_full/best_model.pth

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model tinyunet_full \
--base_channels 32 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/tinyunet32_full80

# %%
# !python train.py \
--data_dir preprocessed \
--train_split preprocessed/splits/train.txt \
--val_split preprocessed/splits/val.txt \
--model tinyunet_baseline \
--base_channels 16 \
--epochs 250 \
--lr 2e-4 \
--batch_size 1 \
--out_dir outputs/tinyunet16_baseline
